# %%
sentence = "God of War is an action-adventure game franchise created by David Jaffe and developed by Sony's Santa Monica Studio. It began in 2005 on the PlayStation 2 (PS2) video game console and has become a flagship series for PlayStation, consisting of nine installments across multiple platforms. Based on ancient mythologies, the series' plot follows Kratos, a Spartan warrior who becomes the God of War and comes into conflict with various mythological pantheons. The earlier games in the series are based on Greek mythology and see Kratos follow a path of vengeance against the Olympian gods; the later games are based on Norse mythology and see Kratos on a path of redemption while also introducing his son Atreus as a secondary protagonist, as they come into conflict or interact with various Norse deities and figures"

# %%
import nltk
word=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(word)
tag_elements
# Out:
# [('God', 'NNP'),
#  ('of', 'IN'),
#  ('War', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('action-adventure', 'JJ'),
#  ('game', 'NN'),
#  ('franchise', 'NN'),
#  ('created', 'VBN'),
#  ('by', 'IN'),
#  ('David', 'NNP'),
#  ('Jaffe', 'NNP'),
#  ('and', 'CC'),
#  ('developed', 'VBN'),
#  ('by', 'IN'),
#  ('Sony', 'NNP'),
#  ("'s", 'POS'),
#  ('Santa', 'NNP'),
#  ('Monica', 'NNP'),
#  ('Studio', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('began', 'VBD'),
#  ('in', 'IN'),
#  ('2005', 'CD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('PlayStation', 'NNP'),
#  ('2', 'CD'),
#  ('(', '('),
#  ('PS2', 'NNP'),
#  (')', ')'),
#  ('video', 'NN'),
#  ('game', 'NN'),
#  ('console', 'NN'),
#  ('and', 'CC'),
#  ('has', 'VBZ'),
#  ('become', 'VBN'),
#  ('a', 'DT'),
#  ('flagship', 'NN'),
#  ('series', 'NN'),
#  ('for', 'IN'),
#  ('PlayStation', 'NNP'),
#  (',', ','),
#  ('consisting', 'VBG'),
#  ('of', 'IN'),
#  ('nine', 'CD'),
#  ('installments', 'NNS'),
#  ('across', 'IN'),
#  ('multiple', 'JJ'),
# ...

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
pip install svgling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
## This part draws out elements, cannot perform in web.
nltk.ne_chunk(tag_elements).draw()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 ## This part draws out elements, cannot perform in web.
# ----> 2 nltk.ne_chunk(tag_elements).draw()
#
# File /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py:761, in Tree.draw(self)
#     756 """
#     757 Open a new window containing a graphical diagram of this tree.
#     758 """
#     759 from nltk.draw.tree import draw_trees
# --> 761 draw_trees(self)
#
# File /usr/local/lib/python3.9/dist-packages/nltk/draw/tree.py:1008, in draw_trees(*trees)
#    1001 def draw_trees(*trees):
#    1002     """
#    1003     Open a new window containing a graphical diagram of the given
#    1004     trees.
#    1005
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#
# ...
