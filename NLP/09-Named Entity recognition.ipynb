# %%
sentence = "God of War is an action-adventure game franchise created by David Jaffe and developed by Sony's Santa Monica Studio. It began in 2005 on the PlayStation 2 (PS2) video game console and has become a flagship series for PlayStation, consisting of nine installments across multiple platforms. Based on ancient mythologies, the series' plot follows Kratos, a Spartan warrior who becomes the God of War and comes into conflict with various mythological pantheons. The earlier games in the series are based on Greek mythology and see Kratos follow a path of vengeance against the Olympian gods; the later games are based on Norse mythology and see Kratos on a path of redemption while also introducing his son Atreus as a secondary protagonist, as they come into conflict or interact with various Norse deities and figures"

# %%
import nltk
word=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(word)
tag_elements
# Out:
# [('God', 'NNP'),
#  ('of', 'IN'),
#  ('War', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('action-adventure', 'JJ'),
#  ('game', 'NN'),
#  ('franchise', 'NN'),
#  ('created', 'VBN'),
#  ('by', 'IN'),
#  ('David', 'NNP'),
#  ('Jaffe', 'NNP'),
#  ('and', 'CC'),
#  ('developed', 'VBN'),
#  ('by', 'IN'),
#  ('Sony', 'NNP'),
#  ("'s", 'POS'),
#  ('Santa', 'NNP'),
#  ('Monica', 'NNP'),
#  ('Studio', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('began', 'VBD'),
#  ('in', 'IN'),
#  ('2005', 'CD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('PlayStation', 'NNP'),
#  ('2', 'CD'),
#  ('(', '('),
#  ('PS2', 'NNP'),
#  (')', ')'),
#  ('video', 'NN'),
#  ('game', 'NN'),
#  ('console', 'NN'),
#  ('and', 'CC'),
#  ('has', 'VBZ'),
#  ('become', 'VBN'),
#  ('a', 'DT'),
#  ('flagship', 'NN'),
#  ('series', 'NN'),
#  ('for', 'IN'),
#  ('PlayStation', 'NNP'),
#  (',', ','),
#  ('consisting', 'VBG'),
#  ('of', 'IN'),
#  ('nine', 'CD'),
#  ('installments', 'NNS'),
#  ('across', 'IN'),
#  ('multiple', 'JJ'),
#  ('platforms', 'NNS'),
#  ('.', '.'),
#  ('Based', 'VBN'),
#  ('on', 'IN'),
#  ('ancient', 'JJ'),
#  ('mythologies', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ("'", 'POS'),
#  ('plot', 'NN'),
#  ('follows', 'VBZ'),
#  ('Kratos', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Spartan', 'NNP'),
#  ('warrior', 'NN'),
#  ('who', 'WP'),
#  ('becomes', 'VBZ'),
#  ('the', 'DT'),
#  ('God', 'NNP'),
#  ('of', 'IN'),
#  ('War', 'NNP'),
#  ('and', 'CC'),
#  ('comes', 'VBZ'),
#  ('into', 'IN'),
#  ('conflict', 'NN'),
#  ('with', 'IN'),
#  ('various', 'JJ'),
#  ('mythological', 'JJ'),
#  ('pantheons', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('earlier', 'JJR'),
#  ('games', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  ('are', 'VBP'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('Greek', 'NNP'),
#  ('mythology', 'NN'),
#  ('and', 'CC'),
#  ('see', 'VB'),
#  ('Kratos', 'NNP'),
#  ('follow', 'VB'),
#  ('a', 'DT'),
#  ('path', 'NN'),
#  ('of', 'IN'),
#  ('vengeance', 'NN'),
#  ('against', 'IN'),
#  ('the', 'DT'),
#  ('Olympian', 'JJ'),
#  ('gods', 'NNS'),
#  (';', ':'),
#  ('the', 'DT'),
#  ('later', 'JJ'),
#  ('games', 'NNS'),
#  ('are', 'VBP'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('Norse', 'NNP'),
#  ('mythology', 'NN'),
#  ('and', 'CC'),
#  ('see', 'VB'),
#  ('Kratos', 'NNP'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('path', 'NN'),
#  ('of', 'IN'),
#  ('redemption', 'NN'),
#  ('while', 'IN'),
#  ('also', 'RB'),
#  ('introducing', 'VBG'),
#  ('his', 'PRP$'),
#  ('son', 'NN'),
#  ('Atreus', 'NNP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('secondary', 'JJ'),
#  ('protagonist', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('come', 'VBP'),
#  ('into', 'IN'),
#  ('conflict', 'NN'),
#  ('or', 'CC'),
#  ('interact', 'NN'),
#  ('with', 'IN'),
#  ('various', 'JJ'),
#  ('Norse', 'NNP'),
#  ('deities', 'NNS'),
#  ('and', 'CC'),
#  ('figures', 'NNS')]

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
nltk.ne_chunk(tag_elements)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File /usr/local/lib/python3.9/dist-packages/nltk/tree/tree.py:782, in Tree._repr_svg_(self)
#     781 def _repr_svg_(self):
# --> 782     from svgling import draw_tree
#     784     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [('God', 'NNP'), ('of', 'IN'), ('War', 'NNP'), ('is', 'VBZ'), ('an', 'DT'), ('action-adventure', 'JJ'), ('game', 'NN'), ('franchise', 'NN'), ('created', 'VBN'), ('by', 'IN'), Tree('PERSON', [('David', 'NNP'), ('Jaffe', 'NNP')]), ('and', 'CC'), ('developed', 'VBN'), ('by', 'IN'), Tree('PERSON', [('Sony', 'NNP')]), ("'s", 'POS'), Tree('PERSON', [('Santa', 'NNP'), ('Monica', 'NNP'), ('Studio', 'NNP')]), ('.', '.'), ('It', 'PRP'), ('began', 'VBD'), ('in', 'IN'), ('2005', 'CD'), ('on', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('PlayStation', 'NNP')]), ('2', 'CD'), ('(', '('), Tree('ORGANIZATION', [('PS2', 'NNP')]), (')', ')'), ('video', 'NN'), ('game', 'NN'), ('console', 'NN'), ('and', 'CC'), ('has', 'VBZ'), ('become', 'VBN'), ('a', 'DT'), ('flagship', 'NN'), ('series', 'NN'), ('for', 'IN'), Tree('ORGANIZATION', [('PlayStation', 'NNP')]), (',', ','), ('consisting', 'VBG'), ('of', 'IN'), ('nine', 'CD'), ('installments', 'NNS'), ('across', 'IN'), ('multiple', 'JJ'), ('platforms', 'NNS'), ('.', '.'), ('Based', 'VBN'), ('on', 'IN'), ('ancient', 'JJ'), ('mythologies', 'NNS'), (',', ','), ('the', 'DT'), ('series', 'NN'), ("'", 'POS'), ('plot', 'NN'), ('follows', 'VBZ'), Tree('PERSON', [('Kratos', 'NNP')]), (',', ','), ('a', 'DT'), Tree('GPE', [('Spartan', 'NNP')]), ('warrior', 'NN'), ('who', 'WP'), ('becomes', 'VBZ'), ('the', 'DT'), ('God', 'NNP'), ('of', 'IN'), ('War', 'NNP'), ('and', 'CC'), ('comes', 'VBZ'), ('into', 'IN'), ('conflict', 'NN'), ('with', 'IN'), ('various', 'JJ'), ('mythological', 'JJ'), ('pantheons', 'NNS'), ('.', '.'), ('The', 'DT'), ('earlier', 'JJR'), ('games', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('series', 'NN'), ('are', 'VBP'), ('based', 'VBN'), ('on', 'IN'), Tree('GPE', [('Greek', 'NNP')]), ('mythology', 'NN'), ('and', 'CC'), ('see', 'VB'), Tree('PERSON', [('Kratos', 'NNP')]), ('follow', 'VB'), ('a', 'DT'), ('path', 'NN'), ('of', 'IN'), ('vengeance', 'NN'), ('against', 'IN'), ('the', 'DT'), Tree('GPE', [('Olympian', 'JJ')]), ('gods', 'NNS'), (';', ':'), ('the', 'DT'), ('later', 'JJ'), ('games', 'NNS'), ('are', 'VBP'), ('based', 'VBN'), ('on', 'IN'), Tree('GPE', [('Norse', 'NNP')]), ('mythology', 'NN'), ('and', 'CC'), ('see', 'VB'), Tree('PERSON', [('Kratos', 'NNP')]), ('on', 'IN'), ('a', 'DT'), ('path', 'NN'), ('of', 'IN'), ('redemption', 'NN'), ('while', 'IN'), ('also', 'RB'), ('introducing', 'VBG'), ('his', 'PRP$'), ('son', 'NN'), Tree('PERSON', [('Atreus', 'NNP')]), ('as', 'IN'), ('a', 'DT'), ('secondary', 'JJ'), ('protagonist', 'NN'), (',', ','), ('as', 'IN'), ('they', 'PRP'), ('come', 'VBP'), ('into', 'IN'), ('conflict', 'NN'), ('or', 'CC'), ('interact', 'NN'), ('with', 'IN'), ('various', 'JJ'), Tree('GPE', [('Norse', 'NNP')]), ('deities', 'NNS'), ('and', 'CC'), ('figures', 'NNS')])
