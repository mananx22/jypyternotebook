# %%
class dog:
    ## constructor this is called when object is created and it requires parameters in order to create object
    def __init__(self,name,age):
        self.name = name
        self.age = age
    # next is methods for class
    def bark(self):
        print(f"{self.name} bhaubhau")

new_dog = dog() ## this will give error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7     def bark(self):
#       8         print(f"{self.name} bhaubhau")
# ---> 10 new_dog = dog() ## this will give error
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'age'

# %%
new_dog = dog("lucy",59)

# %%
print(new_dog.name)
# Out:
# lucy

# %%
new_dog.bark()
# Out:
# lucy bhaubhau
